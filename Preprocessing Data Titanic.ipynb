# %%
import seaborn as sns

# %%
df = sns.load_dataset("titanic")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %% [markdown]
# pada kolom deck adanya missing value dan adanya data tidak terisi (N/A) sebanyak lebih dari 50% maka kita harus menghapus object nya.

# %%
#drop variabel
df.drop('deck', axis = 1, inplace =True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  embark_town  889 non-null    object
#  12  alive        891 non-null    object
#  13  alone        891 non-null    bool
# dtypes: bool(2), category(1), float64(2), int64(4), object(5)
# memory usage: 79.4+ KB

# %% [markdown]
# axis 0 = baris
# axis 1 = kolom

# %%
#drop missing value
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 712 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     712 non-null    int64
#  1   pclass       712 non-null    int64
#  2   sex          712 non-null    object
#  3   age          712 non-null    float64
#  4   sibsp        712 non-null    int64
#  5   parch        712 non-null    int64
#  6   fare         712 non-null    float64
#  7   embarked     712 non-null    object
#  8   class        712 non-null    category
#  9   who          712 non-null    object
#  10  adult_male   712 non-null    bool
#  11  embark_town  712 non-null    object
#  12  alive        712 non-null    object
#  13  alone        712 non-null    bool
# dtypes: bool(2), category(1), float64(2), int64(4), object(5)
# memory usage: 69.0+ KB

# %% [markdown]
# mising pad aembark_town dan embark

# %%
sum(df.duplicated())
# Out:
# 38

# %%
df[df.duplicated()]
# Out:
#      survived  pclass     sex    age  sibsp  parch     fare embarked   class  \
# 133         1       2  female  29.00      1      0  26.0000        S  Second
# 173         0       3    male  21.00      0      0   7.9250        S   Third
# 213         0       2    male  30.00      0      0  13.0000        S  Second
# 313         0       3    male  28.00      0      0   7.8958        S   Third
# 320         0       3    male  22.00      0      0   7.2500        S   Third
# 343         0       2    male  25.00      0      0  13.0000        S  Second
# 355         0       3    male  28.00      0      0   9.5000        S   Third
# 387         1       2  female  36.00      0      0  13.0000        S  Second
# 418         0       2    male  30.00      0      0  13.0000        S  Second
# 476         0       2    male  34.00      1      0  21.0000        S  Second
# 488         0       3    male  30.00      0      0   8.0500        S   Third
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 885    False
# 886     True
# 887    False
# 889    False
# 890    False
# Length: 712, dtype: bool

# %%
df[~df.duplicated()]
#dinegasikan agar yang keluar itu yg false yaitu yg bukan duplicate
df.reset_index(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 712 entries, 0 to 711
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        712 non-null    int64
#  1   survived     712 non-null    int64
#  2   pclass       712 non-null    int64
#  3   sex          712 non-null    object
#  4   age          712 non-null    float64
#  5   sibsp        712 non-null    int64
#  6   parch        712 non-null    int64
#  7   fare         712 non-null    float64
#  8   embarked     712 non-null    object
#  9   class        712 non-null    category
#  10  who          712 non-null    object
#  11  adult_male   712 non-null    bool
#  12  embark_town  712 non-null    object
#  13  alive        712 non-null    object
#  14  alone        712 non-null    bool
# dtypes: bool(2), category(1), float64(2), int64(5), object(5)
# memory usage: 69.1+ KB

# %%
df.head()
# Out:
#    index  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0      0         0       3    male  22.0      1      0   7.2500        S
# 1      1         1       1  female  38.0      1      0  71.2833        C
# 2      2         1       3  female  26.0      0      0   7.9250        S
# 3      3         1       1  female  35.0      1      0  53.1000        S
# 4      4         0       3    male  35.0      0      0   8.0500        S
#
#    class    who  adult_male  embark_town alive  alone
# 0  Third    man        True  Southampton    no  False
# 1  First  woman       False    Cherbourg   yes  False
# 2  Third  woman       False  Southampton   yes   True
# 3  First  woman       False  Southampton   yes  False
# 4  Third    man        True  Southampton    no   True

# %%
#memunculkan data kategori
df.tail(10)
# Out:
#      index  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 702    880         1       2  female  25.0      0      1  26.0000        S
# 703    881         0       3    male  33.0      0      0   7.8958        S
# 704    882         0       3  female  22.0      0      0  10.5167        S
# 705    883         0       2    male  28.0      0      0  10.5000        S
# 706    884         0       3    male  25.0      0      0   7.0500        S
# 707    885         0       3  female  39.0      0      5  29.1250        Q
# 708    886         0       2    male  27.0      0      0  13.0000        S
# 709    887         1       1  female  19.0      0      0  30.0000        S
# 710    889         1       1    male  26.0      0      0  30.0000        C
# 711    890         0       3    male  32.0      0      0   7.7500        Q
#
#       class    who  adult_male  embark_town alive  alone
# 702  Second  woman       False  Southampton   yes  False
# ...

# %% [markdown]
# spearmanr, tau kendall agak sulit digunakan dalam regresi ini.

# %% [markdown]
# ## Menganalisa Data Titanic
# mencari faktor faktor yang mempengaruhi keselamatan penumpang

# %%
sns.histplot(data=df, x='age', hue='alive')
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %% [markdown]
# yes = usia 20-30 selamat
# no = usia 40-60 tidak selamat

# %%
sns.histplot(data=df, x='sex', hue='alive')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='Count'>

# %%
sns.histplot(data=df, x='age', hue='alive', stat='count',element='poly')
#stat=count mengatur jenis dari histogramnya
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
sns.histplot(data=df, x='fare', hue='alive', stat='count',element='poly')
# Out:
# <AxesSubplot:xlabel='fare', ylabel='Count'>

# %%
df[df['sex']=='male']
# Out:
#      level_0  index  survived  pclass   sex   age  sibsp  parch     fare  \
# 0          0      0         0       3  male  22.0      1      0   7.2500
# 4          4      4         0       3  male  35.0      0      0   8.0500
# 5          5      6         0       1  male  54.0      0      0  51.8625
# 6          6      7         0       3  male   2.0      3      1  21.0750
# 11        11     12         0       3  male  20.0      0      0   8.0500
# ..       ...    ...       ...     ...   ...   ...    ...    ...      ...
# 705      705    883         0       2  male  28.0      0      0  10.5000
# 706      706    884         0       3  male  25.0      0      0   7.0500
# 708      708    886         0       2  male  27.0      0      0  13.0000
# 710      710    889         1       1  male  26.0      0      0  30.0000
# 711      711    890         0       3  male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male  embark_town alive  alone
# ...

# %%
sns.histplot(data=df[df['sex']=='male'], x='age', hue='alive', stat='count',element='poly')
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
sns.histplot(data=df[df['sex']=='female'], x='age', hue='alive', stat='count',element='poly')
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %% [markdown]
# anak anak, wanita, dan lansia lebih banyak dilakukan penyelamatan dari pada laki laki

# %%
sns.histplot(data=df[df['sex']=='female'], x='fare', hue='alive', stat='count',element='poly')
# Out:
# <AxesSubplot:xlabel='fare', ylabel='Count'>

# %%
import pandas as pd

# %%
pd.crosstab(df['alive'], df['sex'])
# Out:
# sex    female  male
# alive
# no         64   360
# yes       195    93

# %%
pd.crosstab(df['alive'], df['class'])
# Out:
# class  First  Second  Third
# alive
# no        64      90    270
# yes      120      83     85

# %% [markdown]
# cenderung selamat ada di kelas 1 karena kelas paling mahal

# %%
sns.countplot(data=df, x='class', hue='adult_male')
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %% [markdown]
# ## kesimpulan :
# karakteristik penumpang yang selamat adalah "anak-anak", "wanita", "lansia", dan "first class"
